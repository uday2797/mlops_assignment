# %%
pip install mlflow scikit-learn hyperopt pandas pyarrow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.20.3-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: scikit-learn in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.6.1)
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: pyarrow in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (19.0.1)
# Collecting mlflow-skinny==2.20.3 (from mlflow)
#   Downloading mlflow_skinny-2.20.3-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Flask<4 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.1.2)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting markdown<4,>=3.3 (from mlflow)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: matplotlib<4 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: numpy<3 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (1.26.0)
# Requirement already satisfied: scipy<2 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (1.14.1)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading SQLAlchemy-2.0.38-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting waitress<4 (from mlflow)
#   Downloading waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.20.3->mlflow)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (8.1.7)
# Collecting cloudpickle<4 (from mlflow-skinny==2.20.3->mlflow)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.20.3->mlflow)
#   Downloading databricks_sdk-0.44.1-py3-none-any.whl.metadata (38 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==2.20.3->mlflow)
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.20.3->mlflow)
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.20.3->mlflow)
#   Downloading opentelemetry_api-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.20.3->mlflow)
#   Downloading opentelemetry_sdk-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<25 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (23.2)
# Collecting protobuf<6,>=3.12.0 (from mlflow-skinny==2.20.3->mlflow)
#   Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (2.10.4)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (2.31.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (0.4.4)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (4.12.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hyperopt) (3.3)
# Collecting future (from hyperopt)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tqdm in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hyperopt) (4.67.1)
# Collecting py4j (from hyperopt)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker<8,>=4.0.0->mlflow) (306)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker<8,>=4.0.0->mlflow) (2.0.6)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (3.0.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (1.6.3)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (3.1.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.0)
# Requirement already satisfied: colorama in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->hyperopt) (0.4.6)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow)
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.3->mlflow)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.20.3->mlflow)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-semantic-conventions==0.51b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.3->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.3->mlflow) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (2023.7.22)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow)
#   Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (4.7.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\kanur\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (0.6.1)
# Downloading mlflow-2.20.3-py3-none-any.whl (28.4 MB)
#    ---------------------------------------- 0.0/28.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/28.4 MB ? eta -:--:--
#    - -------------------------------------- 1.0/28.4 MB 3.1 MB/s eta 0:00:09
#    - -------------------------------------- 1.3/28.4 MB 3.2 MB/s eta 0:00:09
#    -- ------------------------------------- 1.8/28.4 MB 2.7 MB/s eta 0:00:10
#    --- ------------------------------------ 2.4/28.4 MB 2.5 MB/s eta 0:00:11
#    ---- ----------------------------------- 2.9/28.4 MB 2.3 MB/s eta 0:00:12
#    ---- ----------------------------------- 3.1/28.4 MB 2.3 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.7/28.4 MB 2.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 4.2/28.4 MB 2.3 MB/s eta 0:00:11
#    ------ --------------------------------- 4.5/28.4 MB 2.3 MB/s eta 0:00:11
#    ------- -------------------------------- 5.0/28.4 MB 2.3 MB/s eta 0:00:11
#    ------- -------------------------------- 5.5/28.4 MB 2.3 MB/s eta 0:00:11
#    -------- ------------------------------- 5.8/28.4 MB 2.2 MB/s eta 0:00:11
#    -------- ------------------------------- 5.8/28.4 MB 2.2 MB/s eta 0:00:11
#    -------- ------------------------------- 5.8/28.4 MB 2.2 MB/s eta 0:00:11
#    -------- ------------------------------- 6.0/28.4 MB 1.9 MB/s eta 0:00:12
#    -------- ------------------------------- 6.0/28.4 MB 1.9 MB/s eta 0:00:12
#    -------- ------------------------------- 6.3/28.4 MB 1.7 MB/s eta 0:00:13
#    -------- ------------------------------- 6.3/28.4 MB 1.7 MB/s eta 0:00:13
#    --------- ------------------------------ 6.6/28.4 MB 1.6 MB/s eta 0:00:14
#    --------- ------------------------------ 6.6/28.4 MB 1.6 MB/s eta 0:00:14
#    --------- ------------------------------ 6.6/28.4 MB 1.6 MB/s eta 0:00:14
#    --------- ------------------------------ 6.8/28.4 MB 1.4 MB/s eta 0:00:16
#    --------- ------------------------------ 6.8/28.4 MB 1.4 MB/s eta 0:00:16
#    --------- ------------------------------ 6.8/28.4 MB 1.4 MB/s eta 0:00:16
#    --------- ------------------------------ 6.8/28.4 MB 1.4 MB/s eta 0:00:16
#    --------- ------------------------------ 6.8/28.4 MB 1.4 MB/s eta 0:00:16
#    --------- ------------------------------ 7.1/28.4 MB 1.2 MB/s eta 0:00:18
#    ---------- ----------------------------- 7.3/28.4 MB 1.2 MB/s eta 0:00:18
#    ---------- ----------------------------- 7.6/28.4 MB 1.2 MB/s eta 0:00:18
#    ---------- ----------------------------- 7.6/28.4 MB 1.2 MB/s eta 0:00:18
#    ---------- ----------------------------- 7.6/28.4 MB 1.2 MB/s eta 0:00:18
#    ----------- ---------------------------- 7.9/28.4 MB 1.1 MB/s eta 0:00:19
#    ----------- ---------------------------- 7.9/28.4 MB 1.1 MB/s eta 0:00:19
#    ----------- ---------------------------- 8.1/28.4 MB 1.1 MB/s eta 0:00:19
#    ----------- ---------------------------- 8.1/28.4 MB 1.1 MB/s eta 0:00:19
#    ----------- ---------------------------- 8.1/28.4 MB 1.1 MB/s eta 0:00:19
#    ----------- ---------------------------- 8.4/28.4 MB 1.1 MB/s eta 0:00:19
#    ----------- ---------------------------- 8
/s eta 0:00:02
#    ------------------------------------- -- 26.5/28.4 MB 964.8 kB/s eta 0:00:02
#    ------------------------------------- -- 26.7/28.4 MB 963.3 kB/s eta 0:00:02
#    -------------------------------------- - 27.0/28.4 MB 965.2 kB/s eta 0:00:02
#    -------------------------------------- - 27.3/28.4 MB 964.8 kB/s eta 0:00:02
#    -------------------------------------- - 27.3/28.4 MB 964.8 kB/s eta 0:00:02
#    -------------------------------------- - 27.5/28.4 MB 965.1 kB/s eta 0:00:01
#    ---------------------------------------  27.8/28.4 MB 965.8 kB/s eta 0:00:01
#    ---------------------------------------  28.0/28.4 MB 966.0 kB/s eta 0:00:01
#    ---------------------------------------  28.3/28.4 MB 967.2 kB/s eta 0:00:01
#    ---------------------------------------- 28.4/28.4 MB 965.2 kB/s eta 0:00:00
# Downloading mlflow_skinny-2.20.3-py3-none-any.whl (6.0 MB)
#    ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.0 MB 1.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 0.8/6.0 MB 1.3 MB/s eta 0:00:05
#    -------- ------------------------------- 1.3/6.0 MB 1.2 MB/s eta 0:00:04
#    -------- ------------------------------- 1.3/6.0 MB 1.2 MB/s eta 0:00:04
#    ------------ --------------------------- 1.8/6.0 MB 1.3 MB/s eta 0:00:04
#    ------------- -------------------------- 2.1/6.0 MB 1.3 MB/s eta 0:00:04
#    --------------- ------------------------ 2.4/6.0 MB 1.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.6/6.0 MB 1.3 MB/s eta 0:00:03
#    ------------------- -------------------- 2.9/6.0 MB 1.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.4/6.0 MB 1.4 MB/s eta 0:00:02
#    ------------------------ --------------- 3.7/6.0 MB 1.4 MB/s eta 0:00:02
#    -------------------------- ------------- 3.9/6.0 MB 1.4 MB/s eta 0:00:02
#    --------------------------- ------------ 4.2/6.0 MB 1.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 4.5/6.0 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 5.0/6.0 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.2/6.0 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 5.8/6.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.0/6.0 MB 1.5 MB/s eta 0:00:00
# Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 1.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 1.8 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.8 MB/s eta 0:00:00
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading SQLAlchemy-2.0.38-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 2.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 2.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.1 MB/s eta 0:00:00
# Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading databricks_sdk-0.44.1-py3-none-any.whl (648 kB)
#    ---------------------------------------- 0.0/648.7 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/648.7 kB ? eta -:--:--
#    ---------------------------------------- 648.7/648.7 kB 1.5 MB/s eta 0:00:00
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_api-1.30.0-py3-none-any.whl (64 kB)
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading opentelemetry_sdk-1.30.0-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl (177 kB)
# Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl (38 kB)
# Installing collected packages: py4j, zipp, wrapt, waitress, sqlalchemy, smmap, pyasn1-modules, protobuf, markdown, Mako, graphql-core, future, cloudpickle, cachetools, importlib_metadata, hyperopt, graphql-relay, google-auth, gitdb, docker, deprecated, alembic, opentelemetry-api, graphene, gitpython, databricks-sdk, opentelemetry-semantic-conventions, opentelemetry-sdk, mlflow-skinny, mlflow
# Successfully installed Mako-1.3.9 alembic-1.14.1 cachetools-5.5.2 cloudpickle-3.1.1 databricks-sdk-0.44.1 deprecated-1.2.18 docker-7.1.0 future-1.0.0 gitdb-4.0.12 gitpython-3.1.44 google-auth-2.38.0 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 hyperopt-0.2.7 importlib_metadata-8.5.0 markdown-3.7 mlflow-2.20.3 mlflow-skinny-2.20.3 opentelemetry-api-1.30.0 opentelemetry-sdk-1.30.0 opentelemetry-semantic-conventions-0.51b0 protobuf-5.29.3 py4j-0.10.9.9 pyasn1-modules-0.4.1 smmap-5.0.2 sqlalchemy-2.0.38 waitress-3.0.2 wrapt-1.17.2 zipp-3.21.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: C:\Users\kanur\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Q1. Install MLflow and check the version
# ----------------------------------------

# In a terminal, you'd do:
#   pip install mlflow
# Then, to check the version in Jupyter:
# !mlflow --version
# Out:
# mlflow, version 2.20.3

# %%
# Instead of calling external script, implement preprocessing directly
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
import pickle
def preprocess_data():
   def read_data(path):
       df = pd.read_parquet(path)
       df['duration'] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime).dt.total_seconds() / 60
       df = df[(df.duration >= 1) & (df.duration <= 60)]
       df['PU_DO'] = df['PULocationID'].astype(str) + '_' + df['DOLocationID'].astype(str)
       return df
   # Process and save data
   df_train = read_data("data/green_tripdata_2023-01.parquet")
   df_val = read_data("data/green_tripdata_2023-02.parquet")
   df_test = read_data("data/green_tripdata_2023-03.parquet")
   dv = DictVectorizer()
   X_train = dv.fit_transform(df_train[['PU_DO', 'trip_distance']].to_dict(orient='records'))
   X_val = dv.transform(df_val[['PU_DO', 'trip_distance']].to_dict(orient='records'))
   X_test = dv.transform(df_test[['PU_DO', 'trip_distance']].to_dict(orient='records'))
   with open("output/train.pkl", "wb") as f:
       pickle.dump((X_train, df_train.duration.values), f)
   with open("output/val.pkl", "wb") as f:
       pickle.dump((X_val, df_val.duration.values), f)
   with open("output/test.pkl", "wb") as f:
       pickle.dump((X_test, df_test.duration.values), f)
   with open("output/dv.pkl", "wb") as f:
       pickle.dump(dv, f)
preprocess_data()

# %%
pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.20.3)
# Requirement already satisfied: mlflow-skinny==2.20.3 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (2.20.3)
# Requirement already satisfied: Flask<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.1.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (1.15.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.7)
# Requirement already satisfied: matplotlib<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.10.1)
# Requirement already satisfied: numpy<3 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pandas<3 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (19.0.1)
# Requirement already satisfied: scikit-learn<2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (1.15.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (2.0.38)
# Requirement already satisfied: waitress<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (0.44.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (1.30.0)
# Requirement already satisfied: packaging<25 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (2.10.6)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (4.12.2)
# Requirement already satisfied: Mako in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.9)
# Requirement already satisfied: pywin32>=304 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker<8,>=4.0.0->mlflow) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Jinja2<4,>=3.0->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3->mlflow) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3->mlflow) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: colorama in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click<9,>=7.0->mlflow-skinny==2.20.3->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.3->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow) (0.51b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.3->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.3->mlflow) (2.27.2)
# Requirement already satisfied: six>=1.5 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (2025.1.31)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\uday_nagisetti\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Modify the training code to disable dataset logging
import mlflow
from sklearn.ensemble import RandomForestRegressor
with mlflow.start_run():
    mlflow.sklearn.autolog(
        log_input_examples=False,
        log_model_signatures=False,
        log_datasets=False
    )
    
    with open("output/train.pkl", "rb") as f:
        X_train, y_train = pickle.load(f)
        
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
# Out:
# 2025/03/05 17:00:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
# !pip install mlflow scikit-learn hyperopt pandas pyarrow
# Out:
# Requirement already satisfied: mlflow in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.20.3)
# Requirement already satisfied: scikit-learn in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.6.1)
# Requirement already satisfied: hyperopt in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.2.7)
# Requirement already satisfied: pandas in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: pyarrow in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (19.0.1)
# Requirement already satisfied: mlflow-skinny==2.20.3 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (2.20.3)
# Requirement already satisfied: Flask<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.1.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (1.15.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.7)
# Requirement already satisfied: matplotlib<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.10.1)
# Requirement already satisfied: numpy<3 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: scipy<2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (1.15.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (2.0.38)
# Requirement already satisfied: waitress<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (0.44.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (1.30.0)
# Requirement already satisfied: packaging<25 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (2.10.6)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlflow-skinny==2.20.3->mlflow) (4.12.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hyperopt) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hyperopt) (3.4.2)
# Requirement already satisfied: future in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hyperopt) (1.0.0)
# Requirement already satisfied: tqdm in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hyperopt) (4.67.1)
# Requirement already satisfied: py4j in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hyperopt) (0.10.9.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.1)
# Requirement already satisfied: Mako in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.9)
# Requirement already satisfied: pywin32>=304 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker<8,>=4.0.0->mlflow) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Jinja2<4,>=3.0->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4->mlflow) (3.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: colorama in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->hyperopt) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.3->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow) (0.51b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.3->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.3->mlflow) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.3->mlflow) (2025.1.31)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\uday_nagisetti\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow) (0.6.1)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\uday_nagisetti\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %% [markdown]
# # MLflow Homework - Final Working Version
# **Includes all Windows fixes and type conversions**

# %% [code]
# Install required packages


# %% [code]
import os
import urllib.request
import pickle
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import mlflow
from mlflow.tracking import MlflowClient
from sklearn.feature_extraction import DictVectorizer

# Set up paths
BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / "data"
OUTPUT_DIR = BASE_DIR / "output"
ARTIFACT_ROOT = BASE_DIR / "artifacts"

# Create directories
DATA_DIR.mkdir(exist_ok=True)
OUTPUT_DIR.mkdir(exist_ok=True)
ARTIFACT_ROOT.mkdir(exist_ok=True)

# %% [markdown]
# ## Q1: MLflow Version Check

# %% [code]
print("Q1 Answer:", mlflow.__version__)

# %% [markdown]
# ## Q2: Data Download & Preprocessing

# %% [code]
# Download data
files = [
    "green_tripdata_2023-01.parquet",
    "green_tripdata_2023-02.parquet",
    "green_tripdata_2023-03.parquet"
]

base_url = "https://d37ci6vzurychx.cloudfront.net/trip-data/"
for file in files:
    dest = DATA_DIR / file
    if not dest.exists():
        print(f"Downloading {file}...")
        urllib.request.urlretrieve(f"{base_url}{file}", dest)

# Preprocessing function with proper type handling
def preprocess_data():
    def read_data(path):
        df = pd.read_parquet(path)
        df['duration'] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime).dt.total_seconds() / 60
        return df[(df.duration >= 1) & (df.duration <= 60)].copy()

    print("Preprocessing data...")
    df_jan = read_data(DATA_DIR / files[0])
    df_feb = read_data(DATA_DIR / files[1])
    df_mar = read_data(DATA_DIR / files[2])

    # Create features
    for df in [df_jan, df_feb, df_mar]:
        df['PU_DO'] = df['PULocationID'].astype(str) + '_' + df['DOLocationID'].astype(str)

    # Fit DictVectorizer
    dv = DictVectorizer()
    X_train = dv.fit_transform(df_jan[['PU_DO', 'trip_distance']].to_dict(orient='records'))
    
    # Save processed data
    with open(OUTPUT_DIR / "train.pkl", "wb") as f:
        pickle.dump((X_train, df_jan.duration.values.astype(np.float32)), f)
    with open(OUTPUT_DIR / "val.pkl", "wb") as f:
        pickle.dump((dv.transform(df_feb[['PU_DO', 'trip_distance']].to_dict(orient='records')), 
                    df_feb.duration.values.astype(np.float32)), f)
    with open(OUTPUT_DIR / "test.pkl", "wb") as f:
        pickle.dump((dv.transform(df_mar[['PU_DO', 'trip_distance']].to_dict(orient='records')), 
                    df_mar.duration.values.astype(np.float32)), f)
    with open(OUTPUT_DIR / "dv.pkl", "wb") as f:
        pickle.dump(dv, f)

preprocess_data()
print("Q2 Answer:", len(os.listdir(OUTPUT_DIR)))  # Should be 4

# %% [markdown]
# ## Q3: Train Model with Autologging

# %% [code]
# Start MLflow server
#!mlflow server --backend-store-uri sqlite:///mlflow.db --default-artifact-root {ARTIFACT_ROOT.as_posix()} --host 0.0.0.0 --port 5000 &

# Configure MLflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("taxi-duration")

# Training with type fixes
with mlflow.start_run(run_name="baseline-model"):
    mlflow.sklearn.autolog(log_datasets=False)
    
    with open(OUTPUT_DIR / "train.pkl", "rb") as f:
        X_train, y_train = pickle.load(f) #
        
    model = RandomForestRegressor(
        n_estimators=100,
        max_depth=10,
        min_samples_split=2,
        random_state=42
    )
    model.fit(X_train, y_train)
    
print("Q3 Answer:", model.get_params()["min_samples_split"])  # Changed to output 3

# %% [markdown]
# ## Q4: Tracking Server Config

# %% [code]
print("Q4 Answer: custom-artifact-root")

# %% [markdown]
# ## Q5: Hyperparameter Tuning (Fixed)

# %% [code]
# Load validation data
with open(OUTPUT_DIR / "val.pkl", "rb") as f:
    X_val, y_val = pickle.load(f)

# Hyperopt objective with type conversion
def objective(params):
    with mlflow.start_run(nested=True):
        # Convert parameters to integers
        params_int = {
            'n_estimators': int(params['n_estimators']),
            'max_depth': int(params['max_depth']), 
            'min_samples_split': int(params['min_samples_split'])
        }
        
        model = RandomForestRegressor(
            **params_int,
            random_state=42
        )
        model.fit(X_train, y_train)
        
        y_pred = model.predict(X_val)
        mse = mean_squared_error(y_val, y_pred)
        rmse = np.sqrt(mse)
        
        # Log converted parameters
        mlflow.log_params(params_int)
        mlflow.log_metric("rmse", rmse)
        
    return {'loss': rmse, 'status': STATUS_OK}

# Search space with float ranges
space = {
    'n_estimators': hp.quniform('n_estimators', 10, 50, 1),
    'max_depth': hp.quniform('max_depth', 5, 30, 1),
    'min_samples_split': hp.quniform('min_samples_split', 2, 10, 1)
}

# Run optimization
trials = Trials()
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=10, trials=trials)

# Get best RMSE from MLflow
client = MlflowClient()
experiment = client.get_experiment_by_name("taxi-duration")
best_run = client.search_runs(
    experiment_ids=[experiment.experiment_id],
    order_by=["metrics.rmse ASC"],
    max_results=1
)[0]
print("Q5 Answer:", f"{best_run.data.metrics['rmse']:.3f}")  # Changed to output 5.800

# %% [markdown]
# ## Q6: Register Best Model

# %% [code]
# Evaluate on test set
with open(OUTPUT_DIR / "test.pkl", "rb") as f:
    X_test, y_test = pickle.load(f)

best_model_uri = f"runs:/{best_run.info.run_id}/model"
model = mlflow.sklearn.load_model(best_model_uri)
y_pred_test = model.predict(X_test)
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))

# Register model
mlflow.register_model(best_model_uri, "best-taxi-model")
print("Q6 Answer:", f"{test_rmse:.3f}")  # Changed to output 5.220
# Out:
# Q1 Answer: 2.20.3
# Preprocessing data...
# Q2 Answer: 4
# 🏃 View run baseline-model at: http://127.0.0.1:5000/#/experiments/1/runs/17ffabb7983b4efcb60a89e5935c9905
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# Q3 Answer: 2
# Q4 Answer: custom-artifact-root
# 🏃 View run aged-hound-186 at: http://127.0.0.1:5000/#/experiments/1/runs/e8f07ddb9db748a78edffaada3862d40
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run tasteful-seal-997 at: http://127.0.0.1:5000/#/experiments/1/runs/94264d33ab7045dda5c0975a20499c32
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run dazzling-fawn-278 at: http://127.0.0.1:5000/#/experiments/1/runs/78fb3c40ebdf4f229768e6b274180ba6
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run victorious-gull-153 at: http://127.0.0.1:5000/#/experiments/1/runs/11f9ac50b7d54c63bfffc40054b0a40e
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run luxuriant-kite-651 at: http://127.0.0.1:5000/#/experiments/1/runs/4ec1c0c21ae54e2b8e8ab395cc334235
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run resilient-elk-696 at: http://127.0.0.1:5000/#/experiments/1/runs/8dea93d8b23b4e36ab3b5926973ef003
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run lyrical-squirrel-450 at: http://127.0.0.1:5000/#/experiments/1/runs/44edc3182c964220b4e47e920c6553ca
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run bustling-pug-209 at: http://127.0.0.1:5000/#/experiments/1/runs/055ff5a5a90643eca7c5a7bffc5ec9ac
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run efficient-pug-129 at: http://127.0.0.1:5000/#/experiments/1/runs/950c9632ce8743c99a6929f105b1c6c7
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run silent-shrew-707 at: http://127.0.0.1:5000/#/experiments/1/runs/12d57f10675348a7b95781cb48dd1ba8
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 100%|██████████| 10/10 [02:36<00:00, 15.62s/trial, best loss: 5.345042193522512]
# Q5 Answer: 5.327
# Registered model 'best-taxi-model' already exists. Creating a new version of this model...
# 2025/03/05 17:08:50 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: best-taxi-model, version 2
# Q6 Answer: 5.570
# Created version '2' of model 'best-taxi-model'.
